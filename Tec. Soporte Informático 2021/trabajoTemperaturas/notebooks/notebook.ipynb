# %%
import pandas as pd
import numpy as np
import seaborn as sns

df = pd.read_csv("../data/historico_temperaturas.csv")
df.drop_duplicates()
df.dropna(inplace=True)

df1 = df[["anio", "maxima", "minima", ]]
grafico = sns.pairplot(df1,hue="anio",palette="Spectral")

df2 = df[["anio", "media", ]]
grafico = sns.pairplot(df2,hue="anio",palette="Spectral")

# %% [markdown]
# - ¿En qué año y mes se registró la temperatura máxima media? ¿Y la mínima media?
#
# - ¿Cómo cambió la temperatura a lo largo de los años?
