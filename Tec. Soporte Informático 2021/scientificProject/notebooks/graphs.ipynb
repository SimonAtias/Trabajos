# %%
import matplotlib.pyplot as plt1
import matplotlib.pyplot as plt2
import matplotlib.pyplot as plt3
import numpy as np

arrayTiemposFunciones = [43,47,48,49,50,371,391,395,404,494]
arrayProcesosFunciones = ["1-s/c","0-s/c","4-s/c","3-s/c","2-s/c","1-c/c","2-c/c","5-c/c","4-c/c","3-c/c"]
y_values = np.array(arrayTiemposFunciones)
x_values = np.array(arrayProcesosFunciones)
plt1.bar(x_values,y_values)
plt1.title('Tiempos de la funcion Funciones (s/c=Sin Cluster y c/c=Con Cluster)')
plt1.ylabel("Tiempos")
plt1.xlabel("Procesos")
# Out:
# Text(0.5, 0, 'Procesos')

# %%
arrayTiemposFunciones = [62,66,67,69,71,761,921,962,985,1002]
arrayProcesosFunciones = ["1-s/c","2-s/c","3-s/c","4-s/c","5-s/c","1-c/c","2-c/c","3-c/c","4-c/c","5-c/c"]
y_values = np.array(arrayTiemposFunciones)
x_values = np.array(arrayProcesosFunciones)
plt1.bar(x_values,y_values)
plt1.title('Tiempos de la funcion Reservar (s/c=Sin Cluster y c/c=Con Cluster)')
plt1.ylabel("Tiempos")
plt1.xlabel("Procesos")
# Out:
# Text(0.5, 0, 'Procesos')
