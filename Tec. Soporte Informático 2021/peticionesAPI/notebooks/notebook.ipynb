# %%
import requests
import json


if __name__ == '__main__':

    archivo = open("hola.csv", "w")
    nombres_columnas = "mensaje , status \n"
    archivo.write(nombres_columnas)
    urlStats = "https://api.spotify.com/v1/me/top/artists?time_range=short_term&limit=5"
    headersToken = {
        "Authorization": "Bearer BQBge4YkowH5YKYQ3YkQnweunQ31Qfdtn1622f-X4cOty-Gj8IyFFys7vFbnVDfja7kzP1V9LCTAzyA3CTfYa4xaznKc62KOqkZO2kwzbJNQguoDOXrXJHO_3uWGkVnhU_959M2TYxQ6oYovFY-iJviU"
    }
    data = {}
    res = requests.get(url=urlStats, headers=headersToken)
    print(json.dumps(res.json(), indent=2))

    for i in res['items'][0].name:
        print(i)


    # for i in range(5):
    #     respuesta = requests.get('https://api.spotify.com/v1/me/top/artists?time_range=short_term&limit=5')
    #     respuesta.status_code
    #     informacion = respuesta.json()
    #     print(informacion)
    #     mensaje = informacion["message"]
    #     estado = informacion["status"]
    #
    #     linea = mensaje + "," + estado + "\n"
    #
    #     archivo = open("hola.csv", "a")
    #     archivo.write(linea)
    #     archivo.close()
# Out:
# {
#   "items": [
#     {
#       "external_urls": {
#         "spotify": "https://open.spotify.com/artist/00FQb4jTyendYWaN8pK0wa"
#       },
#       "followers": {
#         "href": null,
#         "total": 14187198
#       },
#       "genres": [
#         "art pop",
#         "pop"
#       ],
#       "href": "https://api.spotify.com/v1/artists/00FQb4jTyendYWaN8pK0wa",
#       "id": "00FQb4jTyendYWaN8pK0wa",
#       "images": [
#         {
#           "height": 640,
#           "url": "https://i.scdn.co/image/ab6761610000e5ebc5903678d3db18e271e42be0",
#           "width": 640
#         },
#         {
#           "height": 320,
#           "url": "https://i.scdn.co/image/ab67616100005174c5903678d3db18e271e42be0",
#           "width": 320
#         },
#         {
#           "height": 160,
#           "url": "https://i.scdn.co/image/ab6761610000f178c5903678d3db18e271e42be0",
#           "width": 160
#         }
#       ],
#       "name": "Lana Del Rey",
#       "popularity": 85,
# ...
